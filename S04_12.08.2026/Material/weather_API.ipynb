# %%
import requests

# %%
API_KEY = "Your_API_KEY"
URL = "https://www.meteosource.com/api/v1/free/point"
params = {
    "place_id": "cairo",
    "sections": "current",
    "units": "metric",
    "key": API_KEY,
}

# %%
response = requests.get(URL, params=params)

# %%
data = response.json()

# %%
print(data)
# Out:
# {'lat': '30.06263N', 'lon': '31.24967E', 'elevation': 23, 'timezone': 'Africa/Cairo', 'units': 'metric', 'current': {'icon': 'sunny', 'icon_num': 2, 'summary': 'Sunny', 'temperature': 34.8, 'wind': {'speed': 3.0, 'angle': 319, 'dir': 'NW'}, 'precipitation': {'total': 0.0, 'type': 'none'}, 'cloud_cover': 0.0}, 'hourly': None, 'daily': None}
